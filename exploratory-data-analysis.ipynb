# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# The data-set aims to answer the following key questions:
#
# - Does various predicting factors which has been chosen initially really affect the Life expectancy? What are the predicting variables actually affecting the life expectancy?
# - Should a country having a lower life expectancy value(<65) increase its healthcare expenditure in order to improve its average lifespan?
# - How does Infant and Adult mortality rates affect life expectancy?
# - Does Life Expectancy has positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol etc.
# - What is the impact of schooling on the lifespan of humans?
# - Does Life Expectancy have positive or negative relationship with drinking alcohol?
# - Do densely populated countries tend to have lower life expectancy?
# - What is the impact of Immunization coverage on life Expectancy?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the data
dataset = pd.read_csv('Life Expectancy Data.csv')

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# Check for missing values
dataset.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
target = 'Life expectancy '
fig, axes = plt.subplots(1, 2, figsize=(12, 8))
sns.histplot(x=target, data=dataset, alpha=0.3, ax=axes[0])
axes[0].set_title('Histogram of Life expectancy', fontsize=14)
sns.kdeplot(x=target, data=dataset, alpha=0.3, ax=axes[1], fill=True)
axes[1].set_title('Density plot of Life expectancy', fontsize=14)
plt.show()
fig.savefig('dist_life_expectancy.jpeg', dpi=82, transparent=False)

# %% [markdown]
# > Verify that the distribution of life expectancy (target) is normal by comparing the mean and the median

# %%
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# This algorithm would take care of spaces at the end
text = 'Samuel '
text = text[0:-1]
print(text[-1])
# Out:
# l

# %%
# This algorithm would take care of spaces at the beginning
text = ' Samuel'
text = text[1:]
print(text[0])
# Out:
# S

# %%
columns = []
for column in dataset.columns:
    if column[0] == ' ':
        column = column[1:] # Remove first space
    if column[-1] == ' ':
        column = column[0:-1] # Remove last space
    columns.append(column)

# %%
dataset.columns = columns # set the updated columns

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
target = 'Life expectancy'

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
num_cols = ['Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
       'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
       'thinness 5-9 years', 'Income composition of resources', 'Schooling'] # continuous
cat_cols = ['Country', 'Year', 'Status'] # categorical

# %%
len(num_cols) # 18 columns are continous
# Out:
# 18

# %%
fig, axes = plt.subplots(3, 6, figsize=(12, 8))
fig.tight_layout(pad=3.0)

idx = 0

for i in range(3):
    for j in range(6):
        sns.scatterplot(x=num_cols[idx], y=target, data=dataset, alpha=0.3, ax=axes[i, j])
        idx = idx + 1

# %%
country_dict = {'Afghanistan': 'AS',
 'Albania': 'EU',
 'Algeria': 'AF',
 'Angola': 'AF',
 'Antigua and Barbuda': 'NA',
 'Argentina': 'SA',
 'Armenia': 'AS',
 'Australia': 'OC',
 'Austria': 'EU',
 'Azerbaijan': 'EU',    
 'Bahamas': 'NA',
 'Bahrain': 'AS',
 'Bangladesh': 'AS',
 'Barbados': 'NA',
 'Belarus': 'EU',
 'Belgium': 'EU',
 'Belize': 'NA',
 'Benin': 'AF',
 'Bhutan': 'AS',
 'Bolivia (Plurinational State of)': 'SA',
 'Bosnia and Herzegovina': 'EU',
 'Botswana': 'AF',
 'Brazil': 'SA',
 'Brunei Darussalam': 'AS',
 'Bulgaria': 'EU',
 'Burkina Faso': 'AF',
 'Burundi': 'AF',
 "Côte d'Ivoire": 'AF',
 'Cabo Verde': 'AF',
 'Cambodia': 'AS',
 'Cameroon': 'EU',
 'Canada': 'NA',
 'Central African Republic': 'AF',
 'Chad': 'AF',
 'Chile': 'SA',
 'China': 'AS',
 'Colombia': 'SA',
 'Comoros': 'AF',
 'Congo': 'AF',
 'Cook Islands': 'OC',
 'Costa Rica': 'NA',
 'Croatia': 'EU',
 'Cuba': 'NA',
 'Cyprus': 'EU',
 'Czechia': 'EU',
 "Democratic People's Republic of Korea": 'AS',
 'Democratic Republic of the Congo': 'AF',
 'Denmark': 'EU',
 'Djibouti': 'AF',
 'Dominica': 'NA',
 'Dominican Republic': 'NA',
 'Ecuador': 'SA',
 'Egypt': 'AF',
 'El Salvador': 'NA',
 'Equatorial Guinea': 'AF',
 'Eritrea': 'AF',
 'Estonia': 'EU',
 'Ethiopia': 'AF',
 'Fiji': 'OC',
 'Finland': 'EU',
 'France': 'EU',
 'Gabon': 'AF',
 'Gambia': 'AF',
 'Georgia': 'EU',
 'Germany': 'EU',
 'Ghana': 'AF',
 'Greece': 'EU',
 'Grenada': 'NA',
 'Guatemala': 'NA',
 'Guinea': 'AF',
 'Guinea-Bissau': 'AF',
 'Guyana': 'SA',
 'Haiti': 'NA',
 'Honduras': 'NA',
 'Hungary': 'EU',
 'Iceland': 'EU',
 'India': 'AS',
 'Indonesia': 'AS',
 'Iran (Islamic Republic of)': 'AS',
 'Iraq': 'AS',
 'Ireland': 'EU',
 'Israel': 'AS',
 'Italy': 'EU',
 'Jamaica': 'NA',
 'Japan': 'AS',
 'Jordan': 'AS',
 'Kazakhstan': 'AS',
 'Kenya': 'AF',
 'Kiribati': 'OC',
 'Kuwait': 'AS',
 'Kyrgyzstan': 'AS',
 "Lao People's Democratic Republic": 'AS',
 'Latvia': 'EU',
 'Lebanon': 'AS',
 'Lesotho': 'AF',
 'Liberia': 'AF',
 'Libya': 'AF',
 'Lithuania': 'EU',
 'Luxembourg': 'EU',
 'Madagascar': 'AF',
 'Malawi': 'AF',
 'Malaysia': 'AS',
 'Maldives': 'AS',
 'Mali': 'AF',
 'Malta': 'EU',
 'Marshall Islands': 'OC',
 'Mauritania': 'AF',
 'Mauritius': 'AF',
 'Mexico': 'NA',
 'Micronesia (Federated States of)': 'OC',
 'Monaco': 'EU',
 'Mongolia': 'AS',
 'Montenegro': 'EU',
 'Morocco': 'AF',
 'Mozambique': 'AF',
 'Myanmar': 'AS',
 'Namibia': 'AF',
 'Nauru': 'OC',
 'Nepal': 'AS',
 'Netherlands': 'EU',
 'New Zealand': 'OC',
 'Nicaragua': 'NA',
 'Niger': 'AF',
 'Nigeria': 'AF',
 'Niue': 'OC',
 'Norway': 'EU',
 'Oman': 'AS',
 'Pakistan': 'AS',
 'Palau': 'OC',
 'Panama': 'NA',
 'Papua New Guinea': 'OC',
 'Paraguay': 'SA',
 'Peru': 'SA',
 'Philippines': 'AS',
 'Poland': 'EU',
 'Portugal': 'EU',
 'Qatar': 'AS',
 'Republic of Korea': 'AS',
 'Republic of Moldova': 'EU',
 'Romania': 'EU',
 'Russian Federation': 'EU',
 'Rwanda': 'AF',
 'Saint Kitts and Nevis': 'NA',
 'Saint Lucia': 'NA',
 'Saint Vincent and the Grenadines': 'NA',
 'Samoa': 'OC',
 'San Marino': 'EU',
 'Sao Tome and Principe': 'AF',
 'Saudi Arabia': 'AS',
 'Senegal': 'AF',
 'Serbia': 'EU',
 'Seychelles': 'AF',
 'Sierra Leone': 'AF',
 'Singapore': 'AS',
 'Slovakia': 'EU',
 'Slovenia': 'EU',
 'Solomon Islands': 'OC',
 'Somalia': 'AF',
 'South Africa': 'AF',
 'South Sudan': 'AF',
 'Spain': 'EU',
 'Sri Lanka': 'AS',
 'Sudan': 'AF',
 'Suriname': 'SA',
 'Swaziland': 'AF',
 'Sweden': 'EU',
 'Switzerland': 'EU',
 'Syrian Arab Republic': 'AF',
 'Tajikistan': 'AS',
 'Thailand': 'AS',
 'The former Yugoslav republic of Macedonia': 'EU',
 'Timor-Leste': 'AS',
 'Togo': 'AF',
 'Tonga': 'OC',
 'Trinidad and Tobago': 'SA',
 'Tunisia': 'AF',
 'Turkey': 'AS',
 'Turkmenistan': 'AS',
 'Tuvalu': 'OC',
 'Uganda': 'AF',
 'Ukraine': 'EU',
 'United Arab Emirates': 'AS',
 'United Kingdom of Great Britain and Northern Ireland': 'EU',
 'United Republic of Tanzania': 'AF',
 'United States of America': 'NA',
 'Uruguay': 'SA',
 'Uzbekistan': 'AS',
 'Vanuatu': 'OC',
 'Venezuela (Bolivarian Republic of)': 'SA',
 'Viet Nam': 'AS',
 'Yemen': 'AS',
 'Zambia': 'AF',
 'Zimbabwe': 'AF'}

# %% [markdown]
# - AF stands for Africa
# - NA stands for North America
# - SA stands for South America
# - OC stands for OCeania/Australia
# - AS stands for Asia
# - EU stands for Europe

# %%
dataset['Continent'] = '' # Will create the continent variable


for idx, row in dataset.iterrows():
    country = row['Country']
    continent = country_dict[country]
    dataset.loc[idx, 'Continent'] = continent

# %%
dataset.tail()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 2933             27     4.36                     0.0         68.0       31
# 2934             26     4.06                     0.0          7.0      998
# 2935             25     4.43                     0.0         73.0      304
# 2936             25     1.72                     0.0         76.0      529
# 2937             24     1.68                     0.0         79.0     1483
#
#       ...  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 8))
dataset['Continent'].value_counts().plot(kind='bar', ax=axes)
plt.title('Distribution of continent', fontsize=16)
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(12, 8))
sns.scatterplot(x='Schooling', y='Life expectancy', hue='Continent', data=dataset)
plt.show()
